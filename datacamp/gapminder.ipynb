# %%
import pandas as pd
data = pd.read_csv('./data/gapminder_gdp_europe.csv', index_col='country')

# %%
data
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
data.columns.str.strip('gdpPercap_')
# Out:
# Index(['1952', '1957', '1962', '1967', '1972', '1977', '1982', '1987', '1992',
#        '1997', '2002', '2007'],
#       dtype='object')

# %%
'aaabbb '.strip('a')
# Out:
# 'bbb '

# %%
data.columns = [value[len('gdpPercap_'):] for value in data.columns]

# %%
data
# Out:
#                                 1952          1957          1962  \
# country
# Albania                  1601.056136   1942.284244   2312.888958
# Austria                  6137.076492   8842.598030  10750.721110
# Belgium                  8343.105127   9714.960623  10991.206760
# Bosnia and Herzegovina    973.533195   1353.989176   1709.683679
# Bulgaria                 2444.286648   3008.670727   4254.337839
# Croatia                  3119.236520   4338.231617   5477.890018
# Czech Republic           6876.140250   8256.343918  10136.867130
# Denmark                  9692.385245  11099.659350  13583.313510
# Finland                  6424.519071   7545.415386   9371.842561
# France                   7029.809327   8662.834898  10560.485530
# Germany                  7144.114393  10187.826650  12902.462910
# Greece                   3530.690067   4916.299889   6017.190733
# Hungary                  5263.673816   6040.180011   7550.359877
# ...

# %%
data[["1952", "1982"]]
# Out:
#                                 1952          1982
# country
# Albania                  1601.056136   3630.880722
# Austria                  6137.076492  21597.083620
# Belgium                  8343.105127  20979.845890
# Bosnia and Herzegovina    973.533195   4126.613157
# Bulgaria                 2444.286648   8224.191647
# Croatia                  3119.236520  13221.821840
# Czech Republic           6876.140250  15377.228550
# Denmark                  9692.385245  21688.040480
# Finland                  6424.519071  18533.157610
# France                   7029.809327  20293.897460
# Germany                  7144.114393  22031.532740
# Greece                   3530.690067  15268.420890
# Hungary                  5263.673816  12545.990660
# Iceland                  7267.688428  23269.607500
# Ireland                  5210.280328  12618.321410
# Italy                    4931.404155  16537.483500
# Montenegro               2647.585601  11222.587620
# ...

# %%
data.loc["Albania":"Belgium", "1952":"1982"]
# Out:
#                 1952         1957          1962          1967          1972  \
# country
# Albania  1601.056136  1942.284244   2312.888958   2760.196931   3313.422188
# Austria  6137.076492  8842.598030  10750.721110  12834.602400  16661.625600
# Belgium  8343.105127  9714.960623  10991.206760  13149.041190  16672.143560
#
#                 1977          1982
# country
# Albania   3533.00391   3630.880722
# Austria  19749.42230  21597.083620
# Belgium  19117.97448  20979.845890

# %%
data.iloc[0:2, :6]
# Out:
#                 1952         1957          1962          1967          1972  \
# country
# Albania  1601.056136  1942.284244   2312.888958   2760.196931   3313.422188
# Austria  6137.076492  8842.598030  10750.721110  12834.602400  16661.625600
#
#                 1977
# country
# Albania   3533.00391
# Austria  19749.42230

# %%
data.to_numpy()[0:2, :6]
# Out:
# array([[ 1601.056136,  1942.284244,  2312.888958,  2760.196931,
#          3313.422188,  3533.00391 ],
#        [ 6137.076492,  8842.59803 , 10750.72111 , 12834.6024  ,
#         16661.6256  , 19749.4223  ]])

# %%
data[data > data.mean()].mean(axis=1)
# Out:
# country
# Albania                            NaN
# Austria                   20411.916279
# Belgium                   19900.758072
# Bosnia and Herzegovina             NaN
# Bulgaria                           NaN
# Croatia                            NaN
# Czech Republic            10762.901735
# Denmark                   21671.824888
# Finland                   17473.722667
# France                    18833.570327
# Germany                   20556.684433
# Greece                    20079.748147
# Hungary                            NaN
# Iceland                   20531.422273
# Ireland                   29208.452105
# Italy                     23161.867585
# Montenegro                         NaN
# Netherlands               21748.852208
# Norway                    26747.306554
# Poland                             NaN
# Portugal                           NaN
# Romania                            NaN
# Serbia                             NaN
# Slovak Republic                    NaN
# ...

# %%
import numpy as np

# %%
a = np.arange(5).astype(float)
a[0] = np.nan
a
# Out:
# array([nan,  1.,  2.,  3.,  4.])

# %%
np.nanmean(a)
# Out:
# 2.5

# %%
np.mean(a)
