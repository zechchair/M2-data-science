# %% [markdown]
# ### Imports

# %%
from tp_knn_source import *
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Question 1

# %% [markdown]
# Each of the functions rand_bi_gauss, rand_tri_gauss, rand_clown and rand_checkers
# generate a distribution of the datasets by randomly sampling points from a probability
# distribution depending on the function

# %% [markdown]
# Generating 4 datasets with these functions and ploting them

# %%
#plot of the rand_bi_gauss generated distribution
plot_2d(rand_bi_gauss()[0], rand_bi_gauss()[1])

# %%
#plot of the rand_tri_gauss generated distribution
plot_2d(rand_tri_gauss()[0], rand_tri_gauss()[1])

# %%
#plot of the rand_checkers generated distribution
plot_2d(rand_checkers()[0], rand_checkers()[1])

# %%
#plot of the rand_clown generated distribution
plot_2d(rand_clown()[0], rand_clown()[1])

# %% [markdown]
# According to the plots, all distributions are complicated to classify but the 2 datasets generated by rand_clown and rand_checkers are more likely easy to classify

# %% [markdown]
# ### Question 2
